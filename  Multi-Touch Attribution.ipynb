# %%
import numpy as np
import random as rm
import pandas as pd

# %%
states = ['Sleep', 'Icecream', 'Run']
transition_names = [['SS', 'SR', 'SI'], ['RS', 'RR', 'RI'], ['IS', 'IR', 'II']]
transition_matrix = [[0.2,0.6,0.2],[0.1,0.6,0.3],[0.2,0.7,0.1]]
df_transition_names = pd.DataFrame(transition_names)
df_transition_matrix = pd.DataFrame(transition_matrix)

# %%
df_transition_names
# Out:
#     0   1   2
# 0  SS  SR  SI
# 1  RS  RR  RI
# 2  IS  IR  II

# %%
df_transition_matrix
# Out:
#      0    1    2
# 0  0.2  0.6  0.2
# 1  0.1  0.6  0.3
# 2  0.2  0.7  0.1

# %%
if round(sum(transition_matrix[0] + transition_matrix[1] + transition_matrix[2]),6) != 3.0:
    print('Something went wrong!')
else:
    print("Don't worry. It's all good my friend.")
# Out:
# Don't worry. It's all good my friend.

# %%
df_channel_attribution = pd.read_csv('channel_attribution.csv')

# %%
len(df_channel_attribution)
# Out:
# 2392

# %%
paths_str = df_channel_attribution.to_string(header=False).split('\n')

# %%
type(paths_str)
# Out:
# list

# %%
df_channel_attribution

# %%
df_channel_attribution
# Out:
#       R05A.01  R05A.02  R05A.03  R05A.04  R05A.05  R05A.06  R05A.07  R05A.08  \
# 0          16        4      3.0      5.0     10.0      8.0      6.0      8.0
# 1           2        1      9.0     10.0      1.0      4.0      3.0     21.0
# 2           9       13     20.0     16.0     15.0     21.0      NaN      NaN
# 3           8       15     20.0     21.0      NaN      NaN      NaN      NaN
# 4          16        9     13.0     20.0     21.0      NaN      NaN      NaN
# 5           1       11      8.0      4.0      9.0     21.0      NaN      NaN
# 6           1        6     10.0     13.0     16.0     20.0     11.0     21.0
# 7          10       11     12.0      4.0     20.0     21.0      NaN      NaN
# 8          16       10      4.0     20.0     21.0      NaN      NaN      NaN
# 9           4       16     15.0     20.0     21.0      NaN      NaN      NaN
# 10          2       10     21.0      NaN      NaN      NaN      NaN      NaN
# ...

# %%
len(paths_str)
# Out:
# 2392

# %%
channel_paths = [' > '.join(row.split()) for row in paths]

# %%
channel_paths[0]
# Out:
# '0 > 16 > 4 > 3.0 > 5.0 > 10.0 > 8.0 > 6.0 > 8.0 > 13.0 > 20.0 > 21.0 > NaN > NaN > NaN > NaN > NaN > NaN > NaN > NaN > NaN > NaN'
